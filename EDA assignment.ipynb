# %% [markdown]
# ##About - Dataset:
#
# The dataset provided for this project is focused on heart failure, a critical medical condition characterized by
# the heart's inability to pump blood effectively, leading to inadequate circulation throughout the body. Here's an
# overview of the dataset:

# %% [markdown]
# ##Title: Heart Failure Clinical Records Dataset
#
# Source: The dataset was collected at the Faisalabad Institute of Cardiology and the Allied Hospital in
# Faisalabad, Punjab, Pakistan, during the period of April to December in 2015. It was later made available on
# Kaggle.
#
#
# Description: The dataset comprises medical records of 299 patients diagnosed with heart failure. These records
# include various clinical, body, and lifestyle information of the patients. The dataset encompasses 13 features,
# providing insights into the patients' health status and potential risk factors for heart failure

# %% [markdown]
# #Features:
#
# Age: The age of the patient (numeric).
#
# Anaemia: Indicates the presence of anemia (binary: 0 for no, 1 for yes).
#
# Creatinine Phosphokinase (CPK): Level of creatinine phosphokinase enzyme in the blood (numeric).
#
# Diabetes: Indicates whether the patient has diabetes (binary: 0 for no, 1 for yes).
#
# Ejection Fraction: Percentage of blood leaving the heart at each contraction (numeric).
#
# High Blood Pressure: Indicates whether the patient has high blood pressure (binary: 0 for no, 1 for yes).
#
# Platelets: Platelet count in the blood (numeric).
#
# Serum Creatinine: Level of creatinine in the blood (numeric).
#
# Serum Sodium: Level of sodium in the blood (numeric).
#
# Sex: Gender of the patient (binary: 0 for female, 1 for male).
#
# Smoking: Indicates whether the patient smokes (binary: 0 for no, 1 for yes).
#
# Time: Follow-up period (in days) for the patient's condition (numeric).

# %%
##importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#reading file
df = pd.read_csv('heart_failure_clinical_records_dataset.csv')

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %% [markdown]
# #Observation:
#
#  Here we observe that no null values are present

# %%
df.dtypes
##All the data points are in correct manner
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
##1.  What is the distribution of age among heart failure patients in the dataset
##for knowing the distribution we use distribution that was availabe on seaborn

sns.distplot(df['age'],kde=True,color='y')
#here we are initialising kde as true to show the distribution with curve
# Out:
# /tmp/ipykernel_124/2421723763.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'],kde=True,color='y')
# <AxesSubplot: xlabel='age', ylabel='Density'>

# %%
# 2. ´ How does the death rate vary with age
df[['age','DEATH_EVENT']]
# Out:
#       age  DEATH_EVENT
# 0    75.0            1
# 1    55.0            1
# 2    65.0            1
# 3    50.0            1
# 4    65.0            1
# ..    ...          ...
# 294  62.0            0
# 295  55.0            0
# 296  45.0            0
# 297  45.0            0
# 298  50.0            0
#
# [299 rows x 2 columns]

# %%
##For knowing the death variant with age we use histogram in sns
#here we are showing death event as a hue
sns.histplot(data=df,x ='age',hue='DEATH_EVENT',multiple='stack')
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %%
##3. ´ What is the percentage of male and female patients in the dataset?
#we have sex feature in that we will take male as 1 and female as 0
sns.histplot(data=df,x ='sex',stat='percent',multiple='stack')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='Percent'>

# %%
##4. How does platelete count vary among age group
plt.figure(figsize=(30,15))
sns.histplot(data=df,x ='platelets',hue='age',multiple='stack')
# Out:
# <AxesSubplot: xlabel='platelets', ylabel='Count'>

# %%
##5. IS there any correlation between cretanine and sodium levels in the blood
corr_matrix = df.corr()
corr_matrix.loc['serum_creatinine','serum_sodium']
# Out:
# -0.18909521009117405

# %% [markdown]
# The values range from -1 to 1, where:
#
# A value of 1 indicates a perfect positive correlation.
#
# A value of -1 indicates a perfect negative correlation.
#
# A value close to 0 indicates no correlation or a very weak correlation.
#
# so, we observe that ,
#
# A correlation coefficient value of -0.18909521009117405 indicates a weak
#
# negative correlation between the two variables
#
#  the correlation coefficient being close to 0 suggests that changes in one
#
#  variable are not associated with consistent changes in the other variable.

# %%
df.head(2)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1

# %%
##6. How does the prvelence of high blood presuure differ between male and females
df['sex']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 294    1
# 295    0
# 296    0
# 297    1
# 298    1
# Name: sex, Length: 299, dtype: int64

# %%
sns.histplot(data=df,x ='high_blood_pressure',hue='sex',kde=True)
# Out:
# <AxesSubplot: xlabel='high_blood_pressure', ylabel='Count'>

# %%
##7. what is the relation between smoking habits and occurence of heart failure
df[['smoking','ejection_fraction']]
# Out:
#      smoking  ejection_fraction
# 0          0                 20
# 1          0                 38
# 2          1                 20
# 3          0                 20
# 4          0                 20
# ..       ...                ...
# 294        1                 38
# 295        0                 38
# 296        0                 60
# 297        1                 38
# 298        1                 45
#
# [299 rows x 2 columns]

# %%
corr_matrix.loc['smoking','ejection_fraction']
# Out:
# -0.06731456733133784

# %% [markdown]
# A correlation of -0.06731456733133784 indicates weak negative correlation.
#
#  the correlation coefficient being close to 0 suggests that changes in one
#
#   variable are not associated with consistent changes in the other variable.

# %%
##8. Are there any noticible patterns in the distribution of death events across different age groups
sns.histplot(data=df,x='DEATH_EVENT',hue='age',kde=True)
plt.figure(figsize=(30,15))

# %%
corr_matrix.loc['age','DEATH_EVENT']
# Out:
# 0.25372854308800347

# %% [markdown]
# A correlation coefficient of 0.25372854308800347 indicates a moderately positive correlation between the two variables
#
# a correlation coefficient of approximately 0.25 suggests that there is some
#
# tendency for the two variables to move together in the same direction, but the
#  relationship is not extremely strong.
#
# Samething we observe from the above graph also

# %%
##9. is there any difference in ejection fraction between patients without and with diabetes
##in diabeties 0 for no and 1 for yes
corr_matrix.loc['ejection_fraction','diabetes']
# Out:
# -0.004850309667580941

# %%
sns.histplot(data=df,x='ejection_fraction',hue='diabetes',kde=True)
plt.figure(figsize=(30,15))

# %% [markdown]
# A correlation of -0.004850309667580941 indicates weak negative correlation.
#
# the correlation coefficient being close to 0 suggests that changes in one
#
# variable are not associated with consistent changes in the other variable.

# %%
corr_matrix.loc['serum_creatinine','DEATH_EVENT']
# Out:
# 0.29427756098414914

# %%
sns.histplot(data=df,x='serum_creatinine',hue='DEATH_EVENT',kde=True)
plt.figure(figsize=(30,15))

# %% [markdown]
# There is a moderatre tendency between serum_cretanine and deathevent.
